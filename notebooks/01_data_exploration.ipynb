# %% [markdown]
# # Data Exploration
# Khám phá và phân tích dataset deepfake

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql import SparkSession

# %%
# Create Spark session
spark = SparkSession.builder \
    .appName("DataExploration") \
    .getOrCreate()

# %%
# TODO: Load and explore data
# - Dataset size
# - Class distribution
# - Image statistics
